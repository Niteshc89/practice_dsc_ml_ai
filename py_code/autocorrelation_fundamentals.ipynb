# %%
import numpy as np 
import datetime as dt
# sample 
data = np.array([1, 2, 3, 4, 5])
# autocorrelation
autocorr = np.correlate(data,data,mode='full')
print(autocorr)

autocorr1 = np.convolve(data,data[::-1],mode="full")
print(autocorr1)

#dt.datetime(2025,1,1).date
#dt.datetime(2025,1,1).strftime("%d%m%Y")

data = np.array([3, 7, 2, 9, 1])
autocorr = np.correlate(data, data, mode='full')

print(autocorr)
# Out:
# [ 5 14 26 40 55 40 26 14  5]
# [ 5 14 26 40 55 40 26 14  5]
# [  3  34  71  62 144  62  71  34   3]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
data = np.array([1, 2, 3, 4, 5])

# Compute autocorrelation
def autocorrelation(x):
    n = len(x)
    mean = np.mean(x)
    var = np.var(x)
    
    result = np.correlate(x - mean, x - mean, mode='full') / (var * n)
    return result[result.size // 2:]

autocorr = autocorrelation(data)

# Plot the autocorrelation
plt.stem(autocorr)
plt.xlabel("Lag")
plt.ylabel("Autocorrelation")
plt.title("Autocorrelation Plot")
plt.show()
